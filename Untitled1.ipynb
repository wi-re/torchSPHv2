# %%
# import os
# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

import time
import torch
from torch_geometric.loader import DataLoader
import argparse
import yaml
from torch_geometric.nn import radius
from torch.optim import Adam
import torch.autograd.profiler as profiler
from torch.profiler import profile, record_function, ProfilerActivity

# from rbfConv import RbfConv
# from dataset import compressedFluidDataset, prepareData

import inspect
import re
def debugPrint(x):
    frame = inspect.currentframe().f_back
    s = inspect.getframeinfo(frame).code_context[0]
    r = re.search(r"\((.*)\)", s).group(1)
    print("{} [{}] = {}".format(r,type(x).__name__, x))
# %matplotlib notebook
import copy

import time
import torch
from torch_geometric.loader import DataLoader
from tqdm.notebook import trange, tqdm
import argparse
import yaml
from torch_geometric.nn import radius
from torch.optim import Adam
import torch.autograd.profiler as profiler
from torch.profiler import profile, record_function, ProfilerActivity

# from rbfConv import RbfConv
# from dataset import compressedFluidDataset, prepareData

import inspect
import re
def debugPrint(x):
    frame = inspect.currentframe().f_back
    s = inspect.getframeinfo(frame).code_context[0]
    r = re.search(r"\((.*)\)", s).group(1)
    print("{} [{}] = {}".format(r,type(x).__name__, x))


import tomli
from scipy.optimize import minimize
import matplotlib.patches as patches
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LogNorm
from matplotlib.ticker import MaxNLocator
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt

import math
from scipy import interpolate

import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

import scipy.special

from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence

import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# import triangle as tr
from scipy.optimize import minimize

# np
from itertools import product

# seed = 0


# import random 
# import numpy as np
# random.seed(seed)
# torch.manual_seed(seed)
# torch.cuda.manual_seed(seed)
# np.random.seed(seed)
# # print(torch.cuda.device_count())
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# # print('running on: ', device)
# torch.set_num_threads(1)

# from joblib import Parallel, delayed

# # from cutlass import *
# # from rbfConv import *
# # from tqdm.notebook import tqdm

# # from datautils import *
# # # from sphUtils import *
# # from lossFunctions import *
# import math
# from scipy import interpolate

# import numpy as np
# %matplotlib notebook
# import matplotlib.pyplot as plt

# import scipy.special

# from numpy.random import MT19937
# from numpy.random import RandomState, SeedSequence

# import ipywidgets as widgets
# from ipywidgets import interact, interact_manual

# # import triangle as tr
# from scipy.optimize import minimize

# # np
# from itertools import product

import numpy as np


def interpolant(t):
    return t*t*t*(t*(t*6 - 15) + 10)


def generate_perlin_noise_2d(
        shape, res, tileable=(False, False), interpolant=interpolant, rng = np.random.default_rng(seed=42)
):
    """Generate a 2D numpy array of perlin noise.

    Args:
        shape: The shape of the generated array (tuple of two ints).
            This must be a multple of res.
        res: The number of periods of noise to generate along each
            axis (tuple of two ints). Note shape must be a multiple of
            res.
        tileable: If the noise should be tileable along each axis
            (tuple of two bools). Defaults to (False, False).
        interpolant: The interpolation function, defaults to
            t*t*t*(t*(t*6 - 15) + 10).

    Returns:
        A numpy array of shape shape with the generated noise.

    Raises:
        ValueError: If shape is not a multiple of res.
    """
    delta = (res[0] / shape[0], res[1] / shape[1])
    d = (shape[0] // res[0], shape[1] // res[1])
    grid = np.mgrid[0:res[0]:delta[0], 0:res[1]:delta[1]]\
             .transpose(1, 2, 0) % 1
    # Gradients
    angles = 2*np.pi*rng.random((res[0]+1, res[1]+1))
    gradients = np.dstack((np.cos(angles), np.sin(angles)))
    if tileable[0]:
        gradients[-1,:] = gradients[0,:]
    if tileable[1]:
        gradients[:,-1] = gradients[:,0]
    gradients = gradients.repeat(d[0], 0).repeat(d[1], 1)
    g00 = gradients[    :-d[0],    :-d[1]]
    g10 = gradients[d[0]:     ,    :-d[1]]
    g01 = gradients[    :-d[0],d[1]:     ]
    g11 = gradients[d[0]:     ,d[1]:     ]
    # Ramps
    n00 = np.sum(np.dstack((grid[:,:,0]  , grid[:,:,1]  )) * g00, 2)
    n10 = np.sum(np.dstack((grid[:,:,0]-1, grid[:,:,1]  )) * g10, 2)
    n01 = np.sum(np.dstack((grid[:,:,0]  , grid[:,:,1]-1)) * g01, 2)
    n11 = np.sum(np.dstack((grid[:,:,0]-1, grid[:,:,1]-1)) * g11, 2)
    # Interpolation
    t = interpolant(grid)
    n0 = n00*(1-t[:,:,0]) + t[:,:,0]*n10
    n1 = n01*(1-t[:,:,0]) + t[:,:,0]*n11
    return np.sqrt(2)*((1-t[:,:,1])*n0 + t[:,:,1]*n1)


def generate_fractal_noise_2d(
        shape, res, octaves=1, persistence=0.5,
        lacunarity=2, tileable=(False, False),
        interpolant=interpolant, seed = 1337
):
    """Generate a 2D numpy array of fractal noise.

    Args:
        shape: The shape of the generated array (tuple of two ints).
            This must be a multiple of lacunarity**(octaves-1)*res.
        res: The number of periods of noise to generate along each
            axis (tuple of two ints). Note shape must be a multiple of
            (lacunarity**(octaves-1)*res).
        octaves: The number of octaves in the noise. Defaults to 1.
        persistence: The scaling factor between two octaves.
        lacunarity: The frequency factor between two octaves.
        tileable: If the noise should be tileable along each axis
            (tuple of two bools). Defaults to (False, False).
        interpolant: The, interpolation function, defaults to
            t*t*t*(t*(t*6 - 15) + 10).

    Returns:
        A numpy array of fractal noise and of shape shape generated by
        combining several octaves of perlin noise.

    Raises:
        ValueError: If shape is not a multiple of
            (lacunarity**(octaves-1)*res).
    """
    rng = np.random.default_rng(seed=seed)
    
    noise = np.zeros(shape)
    frequency = 1
    amplitude = 1
    for _ in range(octaves):
        noise += amplitude * generate_perlin_noise_2d(
            shape, (frequency*res[0], frequency*res[1]), tileable, interpolant, rng
        )
        frequency *= lacunarity
        amplitude *= persistence
    return noise

# %%
#     delta = (res[0] / shape[0], res[1] / shape[1])
#     d = (shape[0] // res[0], shape[1] // res[1])
#     grid = np.mgrid[0:res[0]:delta[0], 0:res[1]:delta[1]]\
#              .transpose(1, 2, 0) % 1
#     # Gradients
#     angles = 2*np.pi*rng.random((res[0]+1, res[1]+1))
#     gradients = np.dstack((np.cos(angles), np.sin(angles)))
#     if tileable[0]:
#         gradients[-1,:] = gradients[0,:]
#     if tileable[1]:
#         gradients[:,-1] = gradients[:,0]
#     gradients = gradients.repeat(d[0], 0).repeat(d[1], 1)
#     g00 = gradients[    :-d[0],    :-d[1]]
#     g10 = gradients[d[0]:     ,    :-d[1]]
#     g01 = gradients[    :-d[0],d[1]:     ]
#     g11 = gradients[d[0]:     ,d[1]:     ]
#     # Ramps
#     n00 = np.sum(np.dstack((grid[:,:,0]  , grid[:,:,1]  )) * g00, 2)
#     n10 = np.sum(np.dstack((grid[:,:,0]-1, grid[:,:,1]  )) * g10, 2)
#     n01 = np.sum(np.dstack((grid[:,:,0]  , grid[:,:,1]-1)) * g01, 2)
#     n11 = np.sum(np.dstack((grid[:,:,0]-1, grid[:,:,1]-1)) * g11, 2)
#     # Interpolation
#     t = interpolant(grid)
#     n0 = n00*(1-t[:,:,0]) + t[:,:,0]*n10
#     n1 = n01*(1-t[:,:,0]) + t[:,:,0]*n11
#     return np.sqrt(2)*((1-t[:,:,1])*n0 + t[:,:,1]*n1)

# %%
seed = 42
rng = np.random.default_rng(seed=seed)
res = [1, 1]
shape = [64, 64]

# %%
fig, axis = plt.subplots(1, 4, figsize=(18,6), sharex = True, sharey = True, squeeze = False)

delta = (res[0] / shape[0], res[1] / shape[1])
d = (shape[0] // res[0], shape[1] // res[1])
grid = np.mgrid[0:res[0]:delta[0], 0:res[1]:delta[1]]\
         .transpose(1, 2, 0) % 1
# Gradients
angles = 2*np.pi*rng.random((res[0]+1, res[1]+1))
gradients = np.dstack((np.cos(angles), np.sin(angles)))

ax = axis[0,0]
im = ax.imshow(angles)
ax.axis('equal')
ax1_divider = make_axes_locatable(ax)
cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
cbar.ax.tick_params(labelsize=8)

ax = axis[0,1]
im = ax.imshow(gradients[:,0])
ax.axis('equal')
ax1_divider = make_axes_locatable(ax)
cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
cbar.ax.tick_params(labelsize=8)

ax = axis[0,2]
im = ax.imshow(gradients[:,1])
ax.axis('equal')
ax1_divider = make_axes_locatable(ax)
cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
cbar.ax.tick_params(labelsize=8)
# Out:
# <img src="data:image/png;base64,..." width="1800">

# %%
p1 = 73856093
p2 = 19349663
p3 = 83492791

# %%
def xorshift(x):
    x = (x ^ (x << 13)) & 0xFFFFFFFF
    x = (x ^ (x >> 17)) & 0xFFFFFFFF
    x = (x ^ (x << 5 )) & 0xFFFFFFFF
    return x

# %%
def getRandom(x):
    r = x
    for i in range(8):
        r = xorshift(r)
    return r / 0xFFFFFFFF

# %%
n = 2**20
inputs = np.arange(n) + 1
vals = []
vals = getRandom(inputs)
# getRandom(2)
# print(vals)

fig, axis = plt.subplots(1, 1, figsize=(12,6), sharex = True, sharey = True, squeeze = False)

axis[0,0].hist(vals,bins = 128, density = True)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
seed = 42

frequency = 1

xs = np.linspace(-10,10,127)
ys = np.linspace(-10,10,127)
xx, yy = np.meshgrid(xs, ys)

iCoordx = np.rint(xx.flatten() / frequency).reshape(xx.shape).astype(int)
iCoordy = np.rint(yy.flatten() / frequency).reshape(xx.shape).astype(int)

fig, axis = plt.subplots(1, 5, figsize=(25,6), sharex = True, sharey = True, squeeze = False)

# ax = axis[0,0]
# im = ax.pcolormesh(xx,yy,iCoordx)
# ax.axis('equal')
# ax1_divider = make_axes_locatable(ax)
# cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
# cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
# cbar.ax.tick_params(labelsize=8)

# ax = axis[0,1]
# im = ax.pcolormesh(xx,yy,iCoordy)
# ax.axis('equal')
# ax1_divider = make_axes_locatable(ax)
# cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
# cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
# cbar.ax.tick_params(labelsize=8)

seeds = (iCoordx * p1 + iCoordy * p2 + seed)  & 0xFFFFFFFF

ax = axis[0,0]
im = ax.pcolormesh(xx,yy,seeds)
ax.axis('equal')
ax1_divider = make_axes_locatable(ax)
cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
cbar.ax.tick_params(labelsize=8)

angles = getRandom(seeds.flatten()).reshape(seeds.shape) * 2 * np.pi

ax = axis[0,1]
im = ax.pcolormesh(xx,yy,angles)
ax.axis('equal')
ax1_divider = make_axes_locatable(ax)
cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
cbar.ax.tick_params(labelsize=8)

# gradients = np.vstack((np.cos(angles), np.sin(angles))).reshape((angles.shape[0], angles.shape[0], 2))
gradX = np.cos(angles)
gradY = np.sin(angles)

ax = axis[0,2]
im = ax.pcolormesh(xx,yy,gradX)
ax.axis('equal')
ax1_divider = make_axes_locatable(ax)
cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
cbar.ax.tick_params(labelsize=8)

ax = axis[0,3]
im = ax.pcolormesh(xx,yy,gradY)
ax.axis('equal')
ax1_divider = make_axes_locatable(ax)
cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
cbar.ax.tick_params(labelsize=8)

fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
seed = 42

n = 32
xs = np.linspace(-5,5,n)
ys = np.linspace(-5,5,n)
xx, yy = np.meshgrid(xs, ys)
p = np.vstack((xx.flatten(),yy.flatten())).transpose()


# print(p)
# p = np.array([[0.25,0.75]])
# frequency = 1/10
frequency = 0.5

def interpolant(t):
    return t*t*t*(t*(t*6 - 15) + 10)
left  = np.floor(p[:,0] * frequency).astype(int)
right = np.ceil (p[:,0] * frequency).astype(int)
lower = np.floor(p[:,1] * frequency).astype(int)
upper = np.ceil (p[:,1] * frequency).astype(int)

def getNoise(iCoordx,iCoordy, seed):
#     print(p1, p2)
    seeds = (iCoordx * p1 + iCoordy * p2 + seed)  & 0xFFFFFFFF
#     print(seeds)
    angles = getRandom(seeds.flatten()) * 2 * np.pi
    gradX = np.cos(angles)
    gradY = np.sin(angles)
    return np.vstack((angles, gradX, gradY)).transpose()
    

def getNoises(left, right, lower, upper, seed = 42):
    return getNoise(left, lower, seed), getNoise(right, lower, seed), getNoise(left, upper, seed), getNoise(right, upper, seed)

# print(left, right, lower, upper)

ll  = np.vstack((left,lower)).transpose() / frequency
lr = np.vstack((right,lower)).transpose() / frequency
ul  = np.vstack((left,upper)).transpose() / frequency
ur = np.vstack((right,upper)).transpose() / frequency

llNoise, lrNoise, ulNoise, urNoise = getNoises(left, right, lower, upper, seed = seed)

llOffset = (p - ll) * frequency
lrOffset = (p - lr) * frequency
ulOffset = (p - ul) * frequency
urOffset = (p - ur) * frequency

llDot = np.einsum('nd, nd -> n', llOffset, llNoise[:,1:])
lrDot = np.einsum('nd, nd -> n', lrOffset, lrNoise[:,1:])
ulDot = np.einsum('nd, nd -> n', ulOffset, ulNoise[:,1:])
urDot = np.einsum('nd, nd -> n', urOffset, urNoise[:,1:])

tx = interpolant(llOffset[:,0]) / frequency
ty = interpolant(llOffset[:,1]) / frequency
tx = interpolant(llOffset[:,0]) 
ty = interpolant(llOffset[:,1]) 

noisel = llDot * (1 - tx) + lrDot * tx
noiseu = ulDot * (1 - tx) + urDot * tx
noise  = noisel * (1 - ty) + noiseu * ty


# print(llDot)

# print(llNoise.shape)
# print(p.shape)
# print(lowerLeft)
# print(lowerLeft.shape)
# offsetlr = p
fig, axis = plt.subplots(1, 5, figsize=(24,6), sharex = False, sharey = False, squeeze = False)

ax = axis[0,0]
ax.set_title('grid plot')
im = ax.scatter(p[:,0], p[:,1])
ax.scatter(ll[:,0], ll[:,1], c = 'red',alpha = 0.25)
ax.scatter(lr[:,0], lr[:,1], c = 'blue',alpha = 0.25)
ax.scatter(ul[:,0], ul[:,1], c = 'green',alpha = 0.25)
ax.scatter(ur[:,0], ur[:,1], c = 'purple',alpha = 0.25)
ax.axis('equal')
ax.set(xlim = (-5,5), ylim = (-5,5))
# ax1_divider = make_axes_locatable(ax)
# cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
# cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
# cbar.ax.tick_params(labelsize=8)
ax = axis[0,1]
ax.set_title('angles')
# im = ax.scatter(p[:,0], p[:,1])
mi = min(llNoise[:,0].min(), lrNoise[:,0].min(), ulNoise[:,0].min(), urNoise[:,0].min())
ma = max(llNoise[:,0].max(), lrNoise[:,0].max(), ulNoise[:,0].max(), urNoise[:,0].max())
im = ax.scatter(ll[:,0], ll[:,1], c = llNoise[:,0], vmin = mi, vmax = ma)
im = ax.scatter(lr[:,0], lr[:,1], c = lrNoise[:,0], vmin = mi, vmax = ma)
im = ax.scatter(ul[:,0], ul[:,1], c = ulNoise[:,0], vmin = mi, vmax = ma)
im = ax.scatter(ur[:,0], ur[:,1], c = urNoise[:,0], vmin = mi, vmax = ma)
ax.axis('equal')
ax.set(xlim = (-5,5), ylim = (-5,5))
ax1_divider = make_axes_locatable(ax)
cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
cbar.ax.tick_params(labelsize=8)

ax = axis[0,2]
ax.set_title('dot products')
# im = ax.scatter(p[:,0], p[:,1])
mi = min(llDot.min(), lrDot.min(), ulDot.min(), urDot.min())
ma = max(llDot.max(), lrDot.max(), ulDot.max(), urDot.max())
im = ax.scatter(ll[:,0], ll[:,1], c = llDot, vmin = mi, vmax = ma)
im = ax.scatter(lr[:,0], lr[:,1], c = lrDot, vmin = mi, vmax = ma)
im = ax.scatter(ul[:,0], ul[:,1], c = ulDot, vmin = mi, vmax = ma)
im = ax.scatter(ur[:,0], ur[:,1], c = urDot, vmin = mi, vmax = ma)

ax.axis('equal')
ax.set(xlim = (-5,5), ylim = (-5,5))
ax1_divider = make_axes_locatable(ax)
cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
cbar.ax.tick_params(labelsize=8)

ax = axis[0,3]
ax.set_title('noise')
im = ax.scatter(p[:,0], p[:,1], c = noise, s = 16)
ax.axis('auto')
ax.set(xlim = (-5,5), ylim = (-5,5))
ax1_divider = make_axes_locatable(ax)
cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
cbar.ax.tick_params(labelsize=8)


# axis[0,0].set_ylim(-1,1)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2400">

# %%
# from scipy import fftpack, ndimage
# fft2 = fftpack.fft2(noise.reshape(xx.shape))

# fig, axis = plt.subplots(1, 2, figsize=(12,6), sharex = False, sharey = False, squeeze = False)
# axis[0,0].pcolormesh(xx, yy, noise.reshape(xx.shape))
# # axis[0,0].axis('equal')

# axis[0,1].imshow(np.log10(abs(fft2)))
# axis[0,1].axis('auto')
# # axis[0,1].axis('equal')

# fig.tight_layout()

# %%
seed = 42

n = 2**16

xs = np.linspace(0,1000,n)
ys = np.linspace(-5,5,1)
xx, yy = np.meshgrid(xs, ys)
p = np.vstack((xx.flatten(),yy.flatten())).transpose()


# print(p)
# p = np.array([[0.25,0.75]])
# frequency = 1/10
# frequency = 1/2
frequency = 0.1

from scipy.special import comb
def interpolant(t):
    return t*t*t*(t*(t*6 - 15) + 10)
def smoothstep(x, x_min=0, x_max=1, N=1):
    x = np.clip((x - x_min) / (x_max - x_min), 0, 1)

    result = 0
    for n in range(0, N + 1):
         result += comb(N + n, n) * comb(2 * N + 1, N - n) * (-x) ** n

    result *= x ** (N + 1)

    return result

left  = np.floor(p[:,0] * (frequency)).astype(int)
right = np.ceil (p[:,0] * (frequency)).astype(int)
lower = np.floor(p[:,1] * (frequency)).astype(int)
upper = np.ceil (p[:,1] * (frequency)).astype(int)

def getRandom(x):
    r = x
    for i in range(16):
        r = xorshift(r)
    return r / 0xFFFFFFFF
p1 = 73856093
p2 = 19349663
p3 = 83492791

# p1 = 1
# p2 = 1
def getNoise(iCoordx,iCoordy, seed):
#     print(p1, p2)
    seeds = (iCoordx * p1 + iCoordy * p2 + seed)  & 0xFFFFFFFF
#     print(seeds)
    angles = getRandom(seeds.flatten()) * 2 * np.pi
    gradX = np.cos(angles)
    gradY = np.sin(angles)
    return np.vstack((angles, gradX, gradY)).transpose()
    

def getNoises(left, right, lower, upper, seed = 42):
    return getNoise(left, lower, seed), getNoise(right, lower, seed), getNoise(left, upper, seed), getNoise(right, upper, seed)

# print(left, right, lower, upper)

ll  = np.vstack((left,lower)).transpose() / (frequency)
lr = np.vstack((right,lower)).transpose() / (frequency)
ul  = np.vstack((left,upper)).transpose() / (frequency)
ur = np.vstack((right,upper)).transpose() / (frequency)

llNoise, lrNoise, ulNoise, urNoise = getNoises(left, right, lower, upper, seed = seed)

llOffset = (p - ll) * (frequency)
lrOffset = (p - lr) * (frequency)
ulOffset = (p - ul) * (frequency)
urOffset = (p - ur) * (frequency)

llDot = np.einsum('nd, nd -> n', llOffset / (np.linalg.norm(llOffset,axis= 1)[:,None] + 1e-9), llNoise[:,1:])
lrDot = np.einsum('nd, nd -> n', lrOffset / (np.linalg.norm(lrOffset,axis= 1)[:,None] + 1e-9),  lrNoise[:,1:])
ulDot = np.einsum('nd, nd -> n', ulOffset / (np.linalg.norm(ulOffset,axis= 1)[:,None] + 1e-9), ulNoise[:,1:])
urDot = np.einsum('nd, nd -> n', urOffset / (np.linalg.norm(urOffset,axis= 1)[:,None] + 1e-9), urNoise[:,1:])
llDot = np.einsum('nd, nd -> n', llOffset, llNoise[:,1:])
lrDot = np.einsum('nd, nd -> n', lrOffset, lrNoise[:,1:])
ulDot = np.einsum('nd, nd -> n', ulOffset, ulNoise[:,1:])
urDot = np.einsum('nd, nd -> n', urOffset, urNoise[:,1:])

print(np.max(np.linalg.norm(llOffset,axis=1)))
print(np.max(llOffset[:,0]))
print(np.max(llOffset[:,1]))
tx = smoothstep(llOffset[:,0])
ty = smoothstep(llOffset[:,1])

noisel = llDot * (1 - tx) + lrDot * tx
noiseu = ulDot * (1 - tx) + urDot * tx
noise  = noisel * (1 - ty) + noiseu * ty


signal = noise - np.mean(noise)
signal = noise
# signal = np.sin(xs * 2 * np.pi * frequency)
window = np.blackman(len(noise))
# signal = signal * window

fft = np.fft.rfft(signal)
fftfreq = np.fft.rfftfreq(signal.size, 1000 / n)

print(fft.shape)
print(fftfreq.shape)

# fft2 = fftpack.fft(noise - np.mean(noise))
# print(fft2)
plt.style.use('dark_background')
fig, axis = plt.subplots(1, 2, figsize=(12,6), sharex = False, sharey = False, squeeze = False)
axis[0,0].plot(xs, signal)
axis[0,1].plot(fftfreq, abs(fft))
axis[0,1].set_xscale('log')
axis[0,1].axvline(frequency, c= 'white',ls= '--')
# for i in np.arange(int((np.max(xs) - np.min(xs) * frequency) / 2) + 1 ):
#     axis[0,0].axvline(i / frequency, c = 'black', ls = '--')
# axis[0,0].set_axis('log')
# axis[0,1].plot(np.imag(fft2))

fig.tight_layout()
# Out:
# 1.117965748850106
# 0.9999237048905173
# 0.5
# (32769,)
# (32769,)
# <img src="data:image/png;base64,..." width="1200">

# %%
seed = 42
frequency = 1

xs = np.linspace(-10,10,127)
ys = np.linspace(-10,10,127)
xx, yy = np.meshgrid(xs, ys)

iCoordx = np.rint(xx.flatten() / frequency).reshape(xx.shape).astype(int)
iCoordy = np.rint(yy.flatten() / frequency).reshape(xx.shape).astype(int)
seeds = (iCoordx * p1 + iCoordy * p2 + seed)  & 0xFFFFFFFF
angles = getRandom(seeds.flatten()).reshape(seeds.shape) * 2 * np.pi
# gradients = np.vstack((np.cos(angles), np.sin(angles))).reshape((angles.shape[0], angles.shape[0], 2))
gradX = np.cos(angles)
gradY = np.sin(angles)

print(gradX.shape)

# fig, axis = plt.subplots(1, 5, figsize=(25,6), sharex = True, sharey = True, squeeze = False)

# # ax = axis[0,0]
# # im = ax.pcolormesh(xx,yy,iCoordx)
# # ax.axis('equal')
# # ax1_divider = make_axes_locatable(ax)
# # cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
# # cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
# # cbar.ax.tick_params(labelsize=8)

# # ax = axis[0,1]
# # im = ax.pcolormesh(xx,yy,iCoordy)
# # ax.axis('equal')
# # ax1_divider = make_axes_locatable(ax)
# # cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
# # cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
# # cbar.ax.tick_params(labelsize=8)


# ax = axis[0,0]
# im = ax.pcolormesh(xx,yy,seeds)
# ax.axis('equal')
# ax1_divider = make_axes_locatable(ax)
# cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
# cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
# cbar.ax.tick_params(labelsize=8)


# ax = axis[0,1]
# im = ax.pcolormesh(xx,yy,angles)
# ax.axis('equal')
# ax1_divider = make_axes_locatable(ax)
# cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
# cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
# cbar.ax.tick_params(labelsize=8)


# ax = axis[0,2]
# im = ax.pcolormesh(xx,yy,gradX)
# ax.axis('equal')
# ax1_divider = make_axes_locatable(ax)
# cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
# cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
# cbar.ax.tick_params(labelsize=8)

# ax = axis[0,3]
# im = ax.pcolormesh(xx,yy,gradY)
# ax.axis('equal')
# ax1_divider = make_axes_locatable(ax)
# cax1 = ax1_divider.append_axes("bottom", size="7%", pad="10%")
# cbar = fig.colorbar(im, cax=cax1,orientation='horizontal')
# cbar.ax.tick_params(labelsize=8)

# fig.tight_layout()

# %%
delta = (res[0] / shape[0], res[1] / shape[1])
d = (shape[0] // res[0], shape[1] // res[1])
grid = np.mgrid[0:res[0]:delta[0], 0:res[1]:delta[1]]\
         .transpose(1, 2, 0) % 1
# print(grid.shape, grid)
# Gradients
angles = 2*np.pi*rng.random((res[0]+1, res[1]+1))
gradients = np.dstack((np.cos(angles), np.sin(angles)))
gradients = gradients.repeat(d[0], 0).repeat(d[1], 1)
g00 = gradients[    :-d[0],    :-d[1]]
g10 = gradients[d[0]:     ,    :-d[1]]
g01 = gradients[    :-d[0],d[1]:     ]
g11 = gradients[d[0]:     ,d[1]:     ]
print(d)
print(g00.shape)
# Ramps
n00 = np.sum(np.dstack((grid[:,:,0]  , grid[:,:,1]  )) * g00, 2)
n10 = np.sum(np.dstack((grid[:,:,0]-1, grid[:,:,1]  )) * g10, 2)
n01 = np.sum(np.dstack((grid[:,:,0]  , grid[:,:,1]-1)) * g01, 2)
n11 = np.sum(np.dstack((grid[:,:,0]-1, grid[:,:,1]-1)) * g11, 2)
print(n00.shape)
# Interpolation
t = interpolant(grid)
n0 = n00*(1-t[:,:,0]) + t[:,:,0]*n10
n1 = n01*(1-t[:,:,0]) + t[:,:,0]*n11
noise = np.sqrt(2)*((1-t[:,:,1])*n0 + t[:,:,1]*n1)
